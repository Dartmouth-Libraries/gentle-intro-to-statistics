# %%
import random

import seaborn as sns

n_sides = 20
n_rolls = 10
n_dice = 2


results = []
for roll in range(n_rolls):
    result = 0
    for die in range(n_dice):
        result += random.randint(1, n_sides)
    results.append(result)
    
sns.histplot(results, binwidth=1)
# Out:
# <AxesSubplot: ylabel='Count'>
